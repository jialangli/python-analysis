# %% [markdown]
# # 项目：整理Netflix电影演员评分数据

# %% [markdown]
# ### 分析目标
# ### 此数据分析的目的是，整理不同流派影视作品，比如喜剧片、动作片、科幻片中，各演员出演作品的平均IMDB评分，从而挖掘出各个流派中的高评分作品演员。
#
# ### 本实战项目的目的在于练习整理数据，从而得到可供下一步分析的数据。

# %% [markdown]
# # 简介

# %% [markdown]
# #### 原始数据集记录了截止至2022年7月美国地区可观看的所有Netflix电视剧及电影数据。数据集包含两个数据表：titles.csv和credits.csv。
#
# #### titles.csv包含电影及电视剧相关信息，包括影视作品ID、标题、类型、描述、流派、IMDB（一个国外的在线评分网站）评分，等等。credits.csv包含超过7万名出现在Netflix影视作品的导演及演员信息，包括名字、影视作品ID、人物名、演职员类型（导演/演员）等。
#
# #### titles.csv每列的含义如下：
#
# #### id：影视作品ID。
# #### title：影视作品标题。
# #### show_type：作品类型，电视节目或电影。
# #### description：简短描述。
# #### release_year：发布年份。
# #### age_certification：适龄认证。
# #### runtime：每集电视剧或电影的长度。
# #### genres：流派类型列表。
# #### production_countries：出品国家列表。
# #### seasons：如果是电视剧，则是季数。
# #### imdb_id：IMDB的ID。
# #### imdb_score：IMDB的评分。
# #### imdb_votes：IMDB的投票数。
# #### tmdb_popularity：TMDB的流行度。
# #### tmdb_score：TMDB的评分。
# #### credits.csv每列的含义如下：
#
# #### person_ID：演职员ID。
# #### id：参与的影视作品ID。
# #### name：姓名。
# #### character_name：角色姓名。
# #### role：演职员类型，演员或导演。

# %% [markdown]
# # 读取数据

# %% [markdown]
# ### 导入数据分析所需要的库，并通过Pandas的read_csv函数，将原始数据文件"titles.csv"里的数据内容，解析为DataFrame并赋值给变量original_titles。将原始数据文件"credits.csv"里的数据内容，解析为DataFrame并赋值给变量original_credits。

# %%
import pandas as pd

# %%
original_credits=pd.read_csv(r"C:\Users\ljl20\Desktop\评估数据实战\评估数据实战2——电影评分\credits.csv")
original_credits
# Out:
#        person_id         id                name                character  \
# 0           3748    tm84618      Robert De Niro            Travis Bickle
# 1          14658    tm84618        Jodie Foster            Iris Steensma
# 2           7064    tm84618       Albert Brooks                      Tom
# 3           3739    tm84618       Harvey Keitel  Matthew 'Sport' Higgins
# 4          48933    tm84618     Cybill Shepherd                    Betsy
# ...          ...        ...                 ...                      ...
# 77796     736339  tm1059008    Adelaida Buscato                María Paz
# 77797     399499  tm1059008  Luz Stella Luengas             Karen Bayona
# 77798     373198  tm1059008         Inés Prieto                    Fanny
# 77799     378132  tm1059008        Isabel Gaona                   Cacica
# 77800    1950416  tm1059008      Julian Gaviria                      NaN
#
#            role
# 0         ACTOR
# 1         ACTOR
# 2         ACTOR
# 3         ACTOR
# ...

# %%
original_titles=pd.read_csv(r"C:\Users\ljl20\Desktop\评估数据实战\评估数据实战2——电影评分\titles.csv")
original_titles
# Out:
#              id                                      title   type  \
# 0      ts300399        Five Came Back: The Reference Films   SHOW
# 1       tm84618                                Taxi Driver  MOVIE
# 2      tm154986                                Deliverance  MOVIE
# 3      tm127384            Monty Python and the Holy Grail  MOVIE
# 4      tm120801                            The Dirty Dozen  MOVIE
# ...         ...                                        ...    ...
# 5845  tm1014599                                  Fine Wine  MOVIE
# 5846   tm898842                                C/O Kaadhal  MOVIE
# 5847  tm1059008                                    Lokillo  MOVIE
# 5848  tm1035612  Dad Stop Embarrassing Me - The Afterparty  MOVIE
# 5849   ts271048         Mighty Little Bheem: Kite Festival   SHOW
#
#                                             description  release_year  \
# 0     This collection includes 12 World War II-era p...          1945
# ...

# %%
original_credits.sample(10)
# Out:
#        person_id         id                name                character  \
# 8442       73467   tm165593      Maree Cheatham              Party Guest
# 7840       11408   tm137342   Fionnula Flanagan             Sister Grace
# 47542      60123   tm433462      Allison McAtee                    Susan
# 14768     316980    tm68436  Sumona Chakravarti          Shruti's Friend
# 37182     341326   tm372305       Antonio Ortiz                    Jorge
# 2164      616437   tm191110          Vern Urich             Man in Water
# 50989       2235   tm936396   Kristin Chenoweth               Aunt Susan
# 71534    1224333   tm860261           Ese Atawo  Ms. Beckman (Chaperone)
# 5000        6693    tm27911      Kevin Corrigan              Cousin Sean
# 77481    2218584  tm1121084      Caren Bautista            Boobie Zombie
#
#         role
# 8442   ACTOR
# 7840   ACTOR
# 47542  ACTOR
# 14768  ACTOR
# 37182  ACTOR
# 2164   ACTOR
# 50989  ACTOR
# 71534  ACTOR
# 5000   ACTOR
# 77481  ACTOR

# %%
original_titles.sample(10)
# Out:
#              id                           title   type  \
# 1840    ts55645                  Five Came Back   SHOW
# 4938   ts302053                     Change Days   SHOW
# 1680   tm421214          Saudi Arabia Uncovered  MOVIE
# 1517   tm207668                          ABCD 2  MOVIE
# 407    tm144345                   Kal Ho Naa Ho  MOVIE
# 4150   tm851912  Gunjan Saxena: The Kargil Girl  MOVIE
# 4031   tm851346                         Residue  MOVIE
# 4902  tm1046627                        Hypnotic  MOVIE
# 3744   ts237773                           Curon   SHOW
# 1559    ts82327                        Три кота   SHOW
#
#                                             description  release_year  \
# 1840  The extraordinary story of how Hollywood chang...          2017
# 4938  Struggling real-life couples date each other's...          2021
# 1680  English reporter and documentarian, James Jone...          2016
# 1517  Childhood friends Suresh and Vinnie want to be...          2015
# ...

# %%
original_credits.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77801 entries, 0 to 77800
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   person_id  77801 non-null  int64
#  1   id         77801 non-null  object
#  2   name       77801 non-null  object
#  3   character  68029 non-null  object
#  4   role       77801 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.0+ MB

# %%
original_titles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5850 entries, 0 to 5849
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    5850 non-null   object
#  1   title                 5849 non-null   object
#  2   type                  5850 non-null   object
#  3   description           5832 non-null   object
#  4   release_year          5850 non-null   int64
#  5   age_certification     3231 non-null   object
#  6   runtime               5850 non-null   int64
#  7   genres                5850 non-null   object
#  8   production_countries  5850 non-null   object
#  9   seasons               2106 non-null   float64
#  10  imdb_id               5447 non-null   object
#  11  imdb_score            5368 non-null   float64
#  12  imdb_votes            5352 non-null   float64
#  13  tmdb_popularity       5759 non-null   float64
#  14  tmdb_score            5539 non-null   float64
# ...

# %%
cleaned_titles = original_titles.copy()
cleaned_credits = original_credits.copy()
cleaned_titles
cleaned_credits
# Out:
#        person_id         id                name                character  \
# 0           3748    tm84618      Robert De Niro            Travis Bickle
# 1          14658    tm84618        Jodie Foster            Iris Steensma
# 2           7064    tm84618       Albert Brooks                      Tom
# 3           3739    tm84618       Harvey Keitel  Matthew 'Sport' Higgins
# 4          48933    tm84618     Cybill Shepherd                    Betsy
# ...          ...        ...                 ...                      ...
# 77796     736339  tm1059008    Adelaida Buscato                María Paz
# 77797     399499  tm1059008  Luz Stella Luengas             Karen Bayona
# 77798     373198  tm1059008         Inés Prieto                    Fanny
# 77799     378132  tm1059008        Isabel Gaona                   Cacica
# 77800    1950416  tm1059008      Julian Gaviria                      NaN
#
#            role
# 0         ACTOR
# 1         ACTOR
# 2         ACTOR
# 3         ACTOR
# ...

# %% [markdown]
# ### 删除列表中没有角色的节目

# %% [markdown]
# ### 先寻找没有角色的节目

# %%
original_credits[(original_credits["character"]).isnull()]
# Out:
#        person_id         id              name character      role
# 36          3308    tm84618   Martin Scorsese       NaN  DIRECTOR
# 59         17727   tm154986      John Boorman       NaN  DIRECTOR
# 106        11475   tm127384       Terry Jones       NaN  DIRECTOR
# 107        11473   tm127384     Terry Gilliam       NaN  DIRECTOR
# 162         1063   tm120801    Robert Aldrich       NaN  DIRECTOR
# ...          ...        ...               ...       ...       ...
# 77776    2363022  tm1097142  Mohamed El-Arkan       NaN     ACTOR
# 77777    1827884  tm1097142     Mohamed Bakir       NaN  DIRECTOR
# 77783     678884  tm1014599      Segun Arinze       NaN     ACTOR
# 77789    1962840  tm1014599     Seyi Babatope       NaN  DIRECTOR
# 77800    1950416  tm1059008    Julian Gaviria       NaN  DIRECTOR
#
# [9772 rows x 5 columns]

# %%
original_credits.dropna(subset=["character"])
# Out:
#        person_id         id                name                character  \
# 0           3748    tm84618      Robert De Niro            Travis Bickle
# 1          14658    tm84618        Jodie Foster            Iris Steensma
# 2           7064    tm84618       Albert Brooks                      Tom
# 3           3739    tm84618       Harvey Keitel  Matthew 'Sport' Higgins
# 4          48933    tm84618     Cybill Shepherd                    Betsy
# ...          ...        ...                 ...                      ...
# 77795     368473  tm1059008        Aída Morales                  Maritza
# 77796     736339  tm1059008    Adelaida Buscato                María Paz
# 77797     399499  tm1059008  Luz Stella Luengas             Karen Bayona
# 77798     373198  tm1059008         Inés Prieto                    Fanny
# 77799     378132  tm1059008        Isabel Gaona                   Cacica
#
#         role
# 0      ACTOR
# 1      ACTOR
# 2      ACTOR
# 3      ACTOR
# 4      ACTOR
# ...

# %% [markdown]
# ### 再次检查是否将没有角色的节目删掉了

# %%
original_credits[(original_credits["character"]=="NaN")]
# Out:
# Empty DataFrame
# Columns: [person_id, id, name, character, role]
# Index: []

# %% [markdown]
# ### 删除没有tmdb_score：TMDB的评分的节目

# %%
original_titles[(original_titles["tmdb_score"]).isnull()]
# Out:
#              id                                title   type  \
# 0      ts300399  Five Came Back: The Reference Films   SHOW
# 56     tm721687                               Vaashi  MOVIE
# 79     tm342996                               Duniya  MOVIE
# 83      ts63001                            High Risk   SHOW
# 84     tm311264                   Muqaddar Ka Faisla  MOVIE
# ...         ...                                  ...    ...
# 5839  tm1165179                          Kongsi Raya  MOVIE
# 5841   tm985215                 Princess 'Daya'Reese  MOVIE
# 5844  tm1074617        Bling Empire - The Afterparty  MOVIE
# 5845  tm1014599                            Fine Wine  MOVIE
# 5846   tm898842                          C/O Kaadhal  MOVIE
#
#                                             description  release_year  \
# 0     This collection includes 12 World War II-era p...          1945
# 56    Ebin Mathew, a budding lawyer ambitiously join...          1983
# ...

# %%
original_titles.dropna(subset=["tmdb_score"])
# Out:
#              id                                      title   type  \
# 1       tm84618                                Taxi Driver  MOVIE
# 2      tm154986                                Deliverance  MOVIE
# 3      tm127384            Monty Python and the Holy Grail  MOVIE
# 4      tm120801                            The Dirty Dozen  MOVIE
# 5       ts22164               Monty Python's Flying Circus   SHOW
# ...         ...                                        ...    ...
# 5842  tm1066324          Super Monsters: Once Upon a Rhyme  MOVIE
# 5843  tm1097142                                   My Bride  MOVIE
# 5847  tm1059008                                    Lokillo  MOVIE
# 5848  tm1035612  Dad Stop Embarrassing Me - The Afterparty  MOVIE
# 5849   ts271048         Mighty Little Bheem: Kite Festival   SHOW
#
#                                             description  release_year  \
# 1     A mentally unstable Vietnam War veteran works ...          1976
# ...

# %% [markdown]
# ### 删除后检查一下有没有删除完

# %%
original_titles[(original_titles["tmdb_score"]=="NaN")]
# Out:
# Empty DataFrame
# Columns: [id, title, type, description, release_year, age_certification, runtime, genres, production_countries, seasons, imdb_id, imdb_score, imdb_votes, tmdb_popularity, tmdb_score]
# Index: []

# %%
original_titles[(original_titles["production_countries"]=="[]")]
# Out:
#              id                                        title   type  \
# 26      ts45948             Monty Python's Fliegender Zirkus   SHOW
# 212    tm255589                                One Last Shot  MOVIE
# 471    tm418157                Monty Python Conquers America  MOVIE
# 554     tm87909  Thomas & Friends: Thomas and the Jet Engine  MOVIE
# 557     ts56595                                     Cocomong   SHOW
# ...         ...                                          ...    ...
# 5823  tm1099342                              Devdas Brothers  MOVIE
# 5840  tm1216735                              Sun of the Soil  MOVIE
# 5842  tm1066324            Super Monsters: Once Upon a Rhyme  MOVIE
# 5846   tm898842                                  C/O Kaadhal  MOVIE
# 5849   ts271048           Mighty Little Bheem: Kite Festival   SHOW
#
#                                             description  release_year  \
# 26    Monty Python's Fliegender Zirkus consisted of ...          1972
# ...

# %% [markdown]
# #### 第二种删除数据的方法如下：使用drop

# %%
#original_titles.drop(original_titles[original_titles["production_countries"]=='[]'].index)

# %% [markdown]
# #### 发现production_countries的每一行变量中有多个值，我们要先对值进行区分，使得每一行变量只出现一个值

# %% [markdown]
# #### 对production_countries的行进行拆分

# %%
original_titles.explode("production_countries")
# Out:
#              id                                      title   type  \
# 0      ts300399        Five Came Back: The Reference Films   SHOW
# 1       tm84618                                Taxi Driver  MOVIE
# 2      tm154986                                Deliverance  MOVIE
# 3      tm127384            Monty Python and the Holy Grail  MOVIE
# 4      tm120801                            The Dirty Dozen  MOVIE
# ...         ...                                        ...    ...
# 5845  tm1014599                                  Fine Wine  MOVIE
# 5846   tm898842                                C/O Kaadhal  MOVIE
# 5847  tm1059008                                    Lokillo  MOVIE
# 5848  tm1035612  Dad Stop Embarrassing Me - The Afterparty  MOVIE
# 5849   ts271048         Mighty Little Bheem: Kite Festival   SHOW
#
#                                             description  release_year  \
# 0     This collection includes 12 World War II-era p...          1945
# ...

# %% [markdown]
# #### 虽然production_countries表示形式是列表，但其实际类型并非字符串列表，而是字符串，无法直接用value_counts统计各个值出现的次数。 我们可以使用Python内置的eval函数，它可以把字符串转换成表达式，所以可以帮我们把表示列表的字符串转换成列表本身。

# %%
original_titles["production_countries"][4]
# Out:
# "['GB', 'US']"

# %%
original_titles["production_countries"] = original_titles["production_countries"].apply(lambda s: eval(s))
original_titles["production_countries"][4]
# Out:
# ['GB', 'US']

# %%
original_titles=original_titles.explode("production_countries")

# %%
original_titles=original_titles.dropna(subset=["production_countries"])

# %% [markdown]
# #### 检查	production_countries的NaN的值有没有删除完

# %% [markdown]
# #### 第一种检查方法

# %%
original_titles["production_countries"].isnull().sum()
# Out:
# 0

# %% [markdown]
# #### 第二种检查方法

# %%
original_titles[(original_titles["production_countries"]=="NaN")]
# Out:
# Empty DataFrame
# Columns: [id, title, type, description, release_year, age_certification, runtime, genres, production_countries, seasons, imdb_id, imdb_score, imdb_votes, tmdb_popularity, tmdb_score]
# Index: []

# %% [markdown]
# ## 检查两个表还有没有需要清洗数据的

# %%
original_credits
# Out:
#        person_id         id                name                character  \
# 0           3748    tm84618      Robert De Niro            Travis Bickle
# 1          14658    tm84618        Jodie Foster            Iris Steensma
# 2           7064    tm84618       Albert Brooks                      Tom
# 3           3739    tm84618       Harvey Keitel  Matthew 'Sport' Higgins
# 4          48933    tm84618     Cybill Shepherd                    Betsy
# ...          ...        ...                 ...                      ...
# 77796     736339  tm1059008    Adelaida Buscato                María Paz
# 77797     399499  tm1059008  Luz Stella Luengas             Karen Bayona
# 77798     373198  tm1059008         Inés Prieto                    Fanny
# 77799     378132  tm1059008        Isabel Gaona                   Cacica
# 77800    1950416  tm1059008      Julian Gaviria                      NaN
#
#            role
# 0         ACTOR
# 1         ACTOR
# 2         ACTOR
# 3         ACTOR
# ...

# %%
original_titles
# Out:
#              id                                      title   type  \
# 0      ts300399        Five Came Back: The Reference Films   SHOW
# 1       tm84618                                Taxi Driver  MOVIE
# 2      tm154986                                Deliverance  MOVIE
# 3      tm127384            Monty Python and the Holy Grail  MOVIE
# 4      tm120801                            The Dirty Dozen  MOVIE
# ...         ...                                        ...    ...
# 5843  tm1097142                                   My Bride  MOVIE
# 5844  tm1074617              Bling Empire - The Afterparty  MOVIE
# 5845  tm1014599                                  Fine Wine  MOVIE
# 5847  tm1059008                                    Lokillo  MOVIE
# 5848  tm1035612  Dad Stop Embarrassing Me - The Afterparty  MOVIE
#
#                                             description  release_year  \
# 0     This collection includes 12 World War II-era p...          1945
# ...

# %% [markdown]
# #### 经过检查，我发现original_titles中的genres这一列存在空值且每一行变量中有多个值，我们要先对值进行区分，使得每一行变量只出现一个值

# %%
original_titles["genres"][2]
# Out:
# "['drama', 'action', 'thriller', 'european']"

# %% [markdown]
# #### 虽然genres表示形式是列表，但其实际类型并非字符串列表，而是字符串，无法直接用genres统计各个值出现的次数。 我们可以使用Python内置的eval函数，它可以把字符串转换成表达式，所以可以帮我们把表示列表的字符串转换成列表本身。

# %%
original_titles["genres"] = original_titles["genres"].apply(lambda s: eval(s))
original_titles["genres"][2]
# Out:
# ['drama', 'action', 'thriller', 'european']

# %% [markdown]
# #### 对genres中的多个变量进行区分，使得每一行变量只出现一个值

# %%
original_titles=original_titles.explode("genres")

# %% [markdown]
# #### 删除genres的空值

# %%
original_titles=original_titles.dropna(subset=["genres"])

# %% [markdown]
# #### 检查 genres的NaN的值有没有删除完

# %%
original_titles["genres"].isnull().sum()
# Out:
# 0

# %% [markdown]
# #### 再次查看original_titles这一列表看看删除效果

# %%
original_titles
# Out:
#              id                                title   type  \
# 0      ts300399  Five Came Back: The Reference Films   SHOW
# 1       tm84618                          Taxi Driver  MOVIE
# 1       tm84618                          Taxi Driver  MOVIE
# 2      tm154986                          Deliverance  MOVIE
# 2      tm154986                          Deliverance  MOVIE
# ...         ...                                  ...    ...
# 5843  tm1097142                             My Bride  MOVIE
# 5843  tm1097142                             My Bride  MOVIE
# 5845  tm1014599                            Fine Wine  MOVIE
# 5845  tm1014599                            Fine Wine  MOVIE
# 5847  tm1059008                              Lokillo  MOVIE
#
#                                             description  release_year  \
# 0     This collection includes 12 World War II-era p...          1945
# 1     A mentally unstable Vietnam War veteran works ...          1976
# ...

# %% [markdown]
# #### 很好，没有问题，李佳朗真牛逼

# %% [markdown]
# #### 再看一下有没有重复的数据

# %%
original_titles.duplicated().sum()
# Out:
# 0

# %%
original_credits.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### tmdb_score：TMDB的评分任然存在NaN值，将存在NaN值的行删掉

# %%
original_titles=original_titles.dropna(subset=["tmdb_score"])
original_titles
# Out:
#              id                 title   type  \
# 1       tm84618           Taxi Driver  MOVIE
# 1       tm84618           Taxi Driver  MOVIE
# 2      tm154986           Deliverance  MOVIE
# 2      tm154986           Deliverance  MOVIE
# 2      tm154986           Deliverance  MOVIE
# ...         ...                   ...    ...
# 5838  tm1053409  Happiness Ever After  MOVIE
# 5843  tm1097142              My Bride  MOVIE
# 5843  tm1097142              My Bride  MOVIE
# 5843  tm1097142              My Bride  MOVIE
# 5847  tm1059008               Lokillo  MOVIE
#
#                                             description  release_year  \
# 1     A mentally unstable Vietnam War veteran works ...          1976
# 1     A mentally unstable Vietnam War veteran works ...          1976
# 2     Intent on seeing the Cahulawassee River before...          1972
# 2     Intent on seeing the Cahulawassee River before...          1972
# ...

# %% [markdown]
# #### 不想再检查还有没有NaN值了，我是懒狗

# %% [markdown]
# #### 将清洗过的数据original_titles转为cleaned_titles

# %%
cleaned_titles=original_titles
cleaned_titles
# Out:
#              id                 title   type  \
# 1       tm84618           Taxi Driver  MOVIE
# 1       tm84618           Taxi Driver  MOVIE
# 2      tm154986           Deliverance  MOVIE
# 2      tm154986           Deliverance  MOVIE
# 2      tm154986           Deliverance  MOVIE
# ...         ...                   ...    ...
# 5838  tm1053409  Happiness Ever After  MOVIE
# 5843  tm1097142              My Bride  MOVIE
# 5843  tm1097142              My Bride  MOVIE
# 5843  tm1097142              My Bride  MOVIE
# 5847  tm1059008               Lokillo  MOVIE
#
#                                             description  release_year  \
# 1     A mentally unstable Vietnam War veteran works ...          1976
# 1     A mentally unstable Vietnam War veteran works ...          1976
# 2     Intent on seeing the Cahulawassee River before...          1972
# 2     Intent on seeing the Cahulawassee River before...          1972
# ...

# %%
cleaned_credits=original_credits
cleaned_credits
# Out:
#        person_id         id                name                character  \
# 0           3748    tm84618      Robert De Niro            Travis Bickle
# 1          14658    tm84618        Jodie Foster            Iris Steensma
# 2           7064    tm84618       Albert Brooks                      Tom
# 3           3739    tm84618       Harvey Keitel  Matthew 'Sport' Higgins
# 4          48933    tm84618     Cybill Shepherd                    Betsy
# ...          ...        ...                 ...                      ...
# 77796     736339  tm1059008    Adelaida Buscato                María Paz
# 77797     399499  tm1059008  Luz Stella Luengas             Karen Bayona
# 77798     373198  tm1059008         Inés Prieto                    Fanny
# 77799     378132  tm1059008        Isabel Gaona                   Cacica
# 77800    1950416  tm1059008      Julian Gaviria                      NaN
#
#            role
# 0         ACTOR
# 1         ACTOR
# 2         ACTOR
# 3         ACTOR
# ...

# %% [markdown]
# #### 合并两张表

# %%
new_chant = pd.merge(cleaned_credits, cleaned_titles, on="id", how="inner")
new_chant
# Out:
#         person_id         id                name      character      role  \
# 0            3748    tm84618      Robert De Niro  Travis Bickle     ACTOR
# 1            3748    tm84618      Robert De Niro  Travis Bickle     ACTOR
# 2           14658    tm84618        Jodie Foster  Iris Steensma     ACTOR
# 3           14658    tm84618        Jodie Foster  Iris Steensma     ACTOR
# 4            7064    tm84618       Albert Brooks            Tom     ACTOR
# ...           ...        ...                 ...            ...       ...
# 280526     736339  tm1059008    Adelaida Buscato      María Paz     ACTOR
# 280527     399499  tm1059008  Luz Stella Luengas   Karen Bayona     ACTOR
# 280528     373198  tm1059008         Inés Prieto          Fanny     ACTOR
# 280529     378132  tm1059008        Isabel Gaona         Cacica     ACTOR
# 280530    1950416  tm1059008      Julian Gaviria            NaN  DIRECTOR
#
#               title   type                                        description  \
# ...

# %% [markdown]
# # 很好，这两个列表我个人觉得应该没有问题了，下面开始数据分析

# %%
groupby_genres_and_person_id = new_chant.groupby(["genres", "person_id"])

# %%
imdb_score_groupby_genres_and_person_id = groupby_genres_and_person_id["imdb_score"].mean()
imdb_score_groupby_genres_and_person_id
# Out:
# genres   person_id
# action   45           5.0
#          48           5.4
#          51           6.4
#          53           6.8
#          54           5.3
#                      ...
# western  2353339      6.9
#          2370848      6.1
#          2398539      3.8
#          2406218      6.0
#          2408082      7.3
# Name: imdb_score, Length: 179574, dtype: float64

# %%
imdb_score_groupby_genres_and_person_id_df = imdb_score_groupby_genres_and_person_id.reset_index()
imdb_score_groupby_genres_and_person_id_df
# Out:
#          genres  person_id  imdb_score
# 0        action         45         5.0
# 1        action         48         5.4
# 2        action         51         6.4
# 3        action         53         6.8
# 4        action         54         5.3
# ...         ...        ...         ...
# 179569  western    2353339         6.9
# 179570  western    2370848         6.1
# 179571  western    2398539         3.8
# 179572  western    2406218         6.0
# 179573  western    2408082         7.3
#
# [179574 rows x 3 columns]

# %%
tmdb_score_groupby_genres_and_person_id = groupby_genres_and_person_id["tmdb_score"].mean()
tmdb_score_groupby_genres_and_person_id
# Out:
# genres   person_id
# action   45           5.3000
#          48           5.8000
#          51           4.3075
#          53           8.0000
#          54           6.8000
#                        ...
# western  2353339      7.3000
#          2370848      6.8000
#          2398539      6.9000
#          2406218      6.1000
#          2408082      7.1450
# Name: tmdb_score, Length: 179574, dtype: float64

# %%
imdb_votes_groupby_genres_and_person_id = groupby_genres_and_person_id["imdb_votes"].max()
imdb_votes_groupby_genres_and_person_id
# Out:
# genres   person_id
# action   45            52709.0
#          48            90097.0
#          51            56275.0
#          53             3657.0
#          54            26422.0
#                         ...
# western  2353339        3682.0
#          2370848        4703.0
#          2398539         129.0
#          2406218       18987.0
#          2408082      144294.0
# Name: imdb_votes, Length: 179574, dtype: float64

# %%
actor_id_with_names = cleaned_credits[['person_id', 'name']].drop_duplicates()
actor_id_with_names.head(10)
# Out:
#    person_id             name
# 0       3748   Robert De Niro
# 1      14658     Jodie Foster
# 2       7064    Albert Brooks
# 3       3739    Harvey Keitel
# 4      48933  Cybill Shepherd
# 5      32267      Peter Boyle
# 6     519612   Leonard Harris
# 7      29068   Diahnne Abbott
# 8     519613      Gino Ardito
# 9       3308  Martin Scorsese

# %% [markdown]
# ## 第一次数据清洗+数据整理+数据分析
# ### 总结：缺点：1.对于数据清洗方面存在清洗方法记不清的情况
# ###             2.在清洗数据时，清洗逻辑混乱，第一步应该做什么，第二步应该做什么不知道
# ###            3.数据分析不熟且应该从多个方面进行分析，如：最大值，平均数等
# ###      改进：1.多加练习
# ###            2.数据清洗步骤：1.先通过info方法得到数据的概括数据（分析可能出错的地方）
# ###                            2.找出并删去空缺值（不影响数据分析的空缺值可以不删）
# ###                            3.看列名，行名和元素有没有意思相同，但是实际值不一样的，将它们进行合并
# ###                            4.评估重复数据看是否需要删去
# ###                            5.评估无效/错误数据
# ###                            6.让每一列是一个变量，每一行是一个观察值，每一个单元格是一个值
# ###     注意：1. 有些元素表示形式是列表，但其实际类型并非字符串列表，而是字符串，无法直接用genres统计各个值出现的次数。
# ###             我们可以使用Python内置的eval函数，它可以把字符串转换成表达式，所以可以帮我们把表示列表的字符串转换成列表本身。
# ###             例：original_titles["genres"] = original_titles["genres"].apply(lambda s: eval(s))
# ###                 original_titles["genres"][2]
# ###           2.行或列一个空出现多个元素，我们要先对值进行区分，使得每一行变量只出现一个值，使用explode函数
# ###              例：original_titles=original_titles.explode("production_countries")
# ####                                                                                                                                                                                        —————2023/10/26
# ####                                                                                                                                                                                                             李佳朗
